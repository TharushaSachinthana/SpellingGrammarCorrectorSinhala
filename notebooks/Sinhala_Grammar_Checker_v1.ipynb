# %%
# to do: complete rules for identify sigular and plural nouns and return grammar corrections based on noun
# following is not completed
"""
# Rule 3: If the sentence does not have either 'මම' or 'අපි' and subject is singular the verb should ends with 'යි',
    #         If the sentence does not have either 'මම' or 'අපි' and subject is plural the verb should ends with 'ති'
    if "මම" not in sentence and "අපි" not in sentence:
        words = sentence.split()
        singular_subjects = ["ගම", "පාසල", "අය"]  # Add more singular subjects as needed
        plural_subjects = ["අයයන්", "දරුවන්", "ගැටලු"]  # Add more plural subjects as needed

        for word in words:
            for subject in singular_subjects:
                if subject in sentence and word.endswith("ති"):
                    corrections.append(
                        f"Incorrect verb ending for singular subject '{subject}'. Replace '{word}' with a verb ending in 'යි'."
                    )

            for subject in plural_subjects:
                if subject in sentence and word.endswith("යි"):
                    corrections.append(
                        f"Incorrect verb ending for plural subject '{subject}'. Replace '{word}' with a verb ending in 'ති'."
                    )
"""

# %%
def grammar_checker(sentence):
    corrections = []

    # Rule 1: If the sentence has "අපි" as the subject, the verb should end with "මු"
    if "අපි" in sentence:
        words = sentence.split()
        if words[-1].endswith("මු"):
            return ["The sentence is grammatically correct."]
        else:
            corrections.append(
                f"Incorrect verb ending for subject 'අපි'. Replace '{words[-1]}' with a verb ending in 'මු'."
            )

    # Rule 2: If the sentence has "මම" as the subject, the verb should end with "මි"
    if "මම" in sentence:
        words = sentence.split()
        if words[-1].endswith("මි"):
            return ["The sentence is grammatically correct."]
        else:
            corrections.append(
                f"Incorrect verb ending for subject 'මම'. Replace '{words[-1]}' with a verb ending in 'මි'."
            )

    # Rule 3: If sentence does not have either "මම" or "අපි" sentence ends with "යි"
    if "මම" not in sentence and "අපි" not in sentence:
        words = sentence.split()
        subject = words[0]
        for word in words:
            if word.endswith("මු"):
                corrections.append(
                    f"Incorrect verb ending for subject {subject}. Replace '{word}' with a verb ending in 'යි'."
                )
            if word.endswith("මි"):
                corrections.append(
                    f"Incorrect verb ending for subject {subject}. Replace '{word}' with a verb ending in 'යි'."
                )

    # Return the corrections or confirm correctness
    if corrections:
        return corrections
    else:
        return ["The sentence is grammatically correct."]

# Test examples
examples = [
    "මම ගීතයක් ගයමි",
    "මම බුඳුන් වදිමි",
    "මම බසයෙන් යයි",
    "මා කවියක් ලියමි",
    "අපි චාරිකාවක් යමු",
    "අපි ආහාර පිසිමු",
    "අප නගරයට යමු",
    "අපි නිවසට යති",
    "ගස සුලඟට වැනෙමි",
    "හිරු නැගෙනහිරින් නැග එයි",
    "මිනිසා රැකියාවට යයි"
]

for example in examples:
    result = grammar_checker(example)
    print(f"Sentence: {example}")
    for res in result:
        print(f"  - {res}")
    print()
# Out:
# Sentence: මම ගීතයක් ගයමි
#   - The sentence is grammatically correct.
#
# Sentence: මම බුඳුන් වදිමි
#   - The sentence is grammatically correct.
#
# Sentence: මම බසයෙන් යයි
#   - Incorrect verb ending for subject 'මම'. Replace 'යයි' with a verb ending in 'මි'.
#
# Sentence: මා කවියක් ලියමි
#   - Incorrect verb ending for subject මා. Replace 'ලියමි' with a verb ending in 'යි'.
#
# Sentence: අපි චාරිකාවක් යමු
#   - The sentence is grammatically correct.
#
# Sentence: අපි ආහාර පිසිමු
#   - The sentence is grammatically correct.
#
# Sentence: අප නගරයට යමු
#   - Incorrect verb ending for subject අප. Replace 'යමු' with a verb ending in 'යි'.
#
# Sentence: අපි නිවසට යති
#   - Incorrect verb ending for subject 'අපි'. Replace 'යති' with a verb ending in 'මු'.
#
# Sentence: ගස සුලඟට වැනෙමි
#   - Incorrect verb ending for subject ගස. Replace 'වැනෙමි' with a verb ending in 'යි'.
#
# Sentence: හිරු නැගෙනහිරින් නැග එයි
#   - The sentence is grammatically correct.
#
# Sentence: මිනිසා රැකියාවට යයි
#   - The sentence is grammatically correct.
